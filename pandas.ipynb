# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import pandas as pd

# %%
data={'a':[1,2,3,4,5],'b':[6,7,8,9,10]}
df=pd.DataFrame(data)
result=df.loc[0]
print(df.head())
print(result)
# Out:
#    a   b
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10
# a    1
# b    6
# Name: 0, dtype: int64

# %%
df=pd.read_csv('./data/googleplaystore.csv')

# %%
df.head()
# Out:
#                                        App       Category  Rating   Reviews  \
# 0  Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9        19
# 1                                 Facebook         SOCIAL     4.1  78158306
# 2                                 Facebook         SOCIAL     4.1  78128208
# 3                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
#
#                  Size        Installs  Type Price Content Rating  \
# 0                3.0M          1,000+  Free     0       Everyone
# 1  Varies with device  1,000,000,000+  Free     0           Teen
# 2  Varies with device  1,000,000,000+  Free     0           Teen
# 3  Varies with device  1,000,000,000+  Free     0       Everyone
# 4  Varies with device  1,000,000,000+  Free     0       Everyone
#
#               Genres    Last Updated         Current Ver         Android Ver
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.sample(10)
# Out:
#                                               App             Category  \
# 5845                                   AY Oakmont   HEALTH_AND_FITNESS
# 366   UC Browser Mini -Tiny Fast Private & Secure        COMMUNICATION
# 910                Crunchyroll - Everything Anime        ENTERTAINMENT
# 7807                       Ultimate Chest Tracker         PRODUCTIVITY
# 8283               Painting Lulu DC Super Friends  BOOKS_AND_REFERENCE
# 8311                               Bike Racing 3D                 GAME
# 6787                         Mediatek SmartDevice                TOOLS
# 6908                            BW COMPANY FINDER             BUSINESS
# 2629                          POF Free Dating App               SOCIAL
# 309                            Truyện Vui Tý Quậy               COMICS
#
#       Rating  Reviews                Size      Installs  Type Price  \
# 5845     NaN        0                 11M           10+  Free     0
# ...

# %%
df.describe()
# Out:
#             Rating       Reviews
# count  9367.000000  1.084100e+04
# mean      4.191513  4.441119e+05
# std       0.515735  2.927629e+06
# min       1.000000  0.000000e+00
# 25%       4.000000  3.800000e+01
# 50%       4.300000  2.094000e+03
# 75%       4.500000  5.476800e+04
# max       5.000000  7.815831e+07

# %%
df['Rating'].value_counts()
# Out:
# Rating
# 4.4    1109
# 4.3    1076
# 4.5    1038
# 4.2     952
# 4.6     823
# 4.1     708
# 4.0     568
# 4.7     499
# 3.9     386
# 3.8     303
# 5.0     274
# 3.7     239
# 4.8     234
# 3.6     174
# 3.5     163
# 3.4     128
# 3.3     102
# 4.9      87
# 3.0      83
# 3.1      69
# 3.2      64
# 2.9      45
# 2.8      42
# 2.7      25
# 2.6      25
# 2.5      21
# 2.3      20
# 2.4      19
# 1.0      16
# 2.2      14
# 1.9      14
# 2.0      12
# 1.7       8
# 2.1       8
# 1.8       8
# 1.6       4
# 1.5       3
# 1.4       3
# 1.2       1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.head()
# Out:
#                                        App       Category  Rating   Reviews  \
# 0  Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9        19
# 1                                 Facebook         SOCIAL     4.1  78158306
# 2                                 Facebook         SOCIAL     4.1  78128208
# 3                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
#
#                  Size        Installs  Type Price Content Rating  \
# 0                3.0M          1,000+  Free     0       Everyone
# 1  Varies with device  1,000,000,000+  Free     0           Teen
# 2  Varies with device  1,000,000,000+  Free     0           Teen
# 3  Varies with device  1,000,000,000+  Free     0       Everyone
# 4  Varies with device  1,000,000,000+  Free     0       Everyone
#
#               Genres    Last Updated         Current Ver         Android Ver
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10840 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  int64
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10841 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
#google play store data

# %% [markdown]
# #importing Liberaries

# %%
df.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 8830

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 316

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 1695

# %%
8829+316+1695
# Out:
# 10840

# %%
df['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
import warnings
warnings.filterwarnings('ignore')

# %%
print(f"the no of rows are: {df.shape[0]}")
print(f"the no of columns are {df.shape[1]}")
# Out:
# the no of rows are: 10841
# the no of columns are 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %% [markdown]
# #how to make numeric columns

# %%
df['Size'].loc[df['Size'].str.contains('M')].value_counts().sum()
# Out:
# 8830

# %%
df['Size'].loc[df['Size'].str.contains('k')].value_counts().sum()
# Out:
# 316

# %%
df['Size'].loc[df['Size'].str.contains('Varies with device')].value_counts().sum()
# Out:
# 1695

# %% [markdown]
# #Convert whole columns into bytes

# %%
def convert_size(size):
    if isinstance(size,str):
        if 'M' in size:
            return float(size.replace('M', ''))*1024*1024
        elif 'k' in size:
            return float(size.replace('k',''))*1024
        elif 'Varies with device' in size:
            return np.nan
    return size

# %%
df['Size']=df['Size'].apply(convert_size)

# %%
df['Size']
# Out:
# 0         3145728.0
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#             ...
# 10836     9332326.4
# 10837    37748736.0
# 10838     1044480.0
# 10839     3250585.6
# 10840    10066329.6
# Name: Size, Length: 10841, dtype: float64

# %%
df.head()
# Out:
#                                        App       Category  Rating   Reviews  \
# 0  Life Made WI-Fi Touchscreen Photo Frame            NaN     1.9        19
# 1                                 Facebook         SOCIAL     4.1  78158306
# 2                                 Facebook         SOCIAL     4.1  78128208
# 3                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
# 4                       WhatsApp Messenger  COMMUNICATION     4.4  69119316
#
#         Size        Installs  Type Price Content Rating             Genres  \
# 0  3145728.0          1,000+  Free     0       Everyone  February 11, 2018
# 1        NaN  1,000,000,000+  Free     0           Teen             Social
# 2        NaN  1,000,000,000+  Free     0           Teen             Social
# 3        NaN  1,000,000,000+  Free     0       Everyone      Communication
# 4        NaN  1,000,000,000+  Free     0       Everyone      Communication
#
#      Last Updated         Current Ver         Android Ver
# ...

# %%
df['size_in_mbs']=df['Size'].apply(lambda x: x/(1024*1024))

# %%
df['Installs'].unique()
# Out:
# array(['10000', '500000', '5000000', '50000000', '100000', '50000',
#        '1000000', '10000000', '5000', '100000000', '1000000000', '1000',
#        '500000000', '50', '100', '500', '10', '1', '5', '0', 'Free'],
#       dtype=object)

# %% [markdown]
# remove + sign
# remove , sign
# convert into int

# %%
df['Installs']=df['Installs'].apply(lambda x: x.replace('+','') if '+' in str(x) else x )
df['Installs']=df['Installs'].apply(lambda x: x.replace(',','') if ',' in str(x) else x)

# %%
df['Installs'].value_counts()
# Out:
# Installs
# 1000000       1579
# 10000000      1252
# 100000        1169
# 10000         1054
# 1000           908
# 5000000        752
# 100            719
# 500000         539
# 50000          479
# 5000           477
# 100000000      409
# 10             386
# 500            330
# 50000000       289
# 50             205
# 5               82
# 500000000       72
# 1               67
# 1000000000      58
# 0               15
# Name: count, dtype: int64

# %%
df['Installs']=df['Installs'].apply(lambda x: int(x))

# %%
df.describe()
# Out:
#             Rating       Reviews          Size      Installs         Price  \
# count  9367.000000  1.084100e+04  9.146000e+03  1.084100e+04  10841.000000
# mean      4.191513  4.441119e+05  2.255921e+07  1.546291e+07      1.027273
# std       0.515735  2.927629e+06  2.368595e+07  8.502557e+07     15.948971
# min       1.000000  0.000000e+00  8.704000e+03  0.000000e+00      0.000000
# 25%       4.000000  3.800000e+01  5.138022e+06  1.000000e+03      0.000000
# 50%       4.300000  2.094000e+03  1.363149e+07  1.000000e+05      0.000000
# 75%       4.500000  5.476800e+04  3.145728e+07  5.000000e+06      0.000000
# max       5.000000  7.815831e+07  1.048576e+08  1.000000e+09    400.000000
#
#        size_in_mbs
# count  9146.000000
# mean     21.514141
# std      22.588679
# min       0.008301
# 25%       4.900000
# 50%      13.000000
# 75%      30.000000
# max     100.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            9146 non-null   object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('$','') if '$'in x else x)

# %%
df['Price'].value_counts()
# Out:
# Price
# 0         10041
# 0.99        148
# 2.99        129
# 1.99         73
# 4.99         72
#           ...
# 19.40         1
# 3.08          1
# 379.99        1
# 2.56          1
# 1.04          1
# Name: count, Length: 92, dtype: int64

# %%
df['Price']=df['Price'].apply(lambda x: x.replace('$','') if '$' in x else x)

# %%
df['Price']=df['Price'].apply(lambda x: float(x))

# %%
df.describe()
# Out:
#             Rating       Reviews          Size         Price  size_in_mbs
# count  9367.000000  1.084100e+04  9.146000e+03  10841.000000  9146.000000
# mean      4.191513  4.441119e+05  2.255921e+07      1.027273    21.514141
# std       0.515735  2.927629e+06  2.368595e+07     15.948971    22.588679
# min       1.000000  0.000000e+00  8.704000e+03      0.000000     0.008301
# 25%       4.000000  3.800000e+01  5.138022e+06      0.000000     4.900000
# 50%       4.300000  2.094000e+03  1.363149e+07      0.000000    13.000000
# 75%       4.500000  5.476800e+04  3.145728e+07      0.000000    30.000000
# max       5.000000  7.815831e+07  1.048576e+08    400.000000   100.000000

# %%
print(f"Min price is: {df['Price'].max()}")
# Out:
# Min price is: 400.0

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df1=pd.read_csv('./data/titanic_cleaned.csv')

# %%
df1.melt(df1)
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Age, SibSp, Parch, Fare, male, Q, S, variable, value]
# Index: []

# %%
df1.sort_values('Pclass',ascending=False)
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  1
# 510         0       3  24.0      0      0   8.0500     1  0  1
# 499         0       3  17.0      0      0   8.6625     1  0  1
# 500         0       3  21.0      0      0   7.7500     0  1  0
# 501         0       3  24.0      0      0   7.6292     0  1  0
# ..        ...     ...   ...    ...    ...      ...   ... .. ..
# 709         1       1  24.0      0      0  49.5042     0  0  0
# 710         0       1  37.0      0      0  26.5500     1  0  1
# 711         1       1  48.0      1      0  52.0000     1  0  1
# 101         0       1  21.0      0      1  77.2875     1  0  1
# 444         1       1   4.0      0      2  81.8583     1  0  1
#
# [889 rows x 9 columns]

# %%
df1.sort_index()
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 0           0       3  22.0      1      0   7.2500     1  0  1
# 1           1       1  38.0      1      0  71.2833     0  0  0
# 2           1       3  26.0      0      0   7.9250     0  0  1
# 3           1       1  35.0      1      0  53.1000     0  0  1
# 4           0       3  35.0      0      0   8.0500     1  0  1
# ..        ...     ...   ...    ...    ...      ...   ... .. ..
# 884         0       2  27.0      0      0  13.0000     1  0  1
# 885         1       1  19.0      0      0  30.0000     0  0  1
# 886         0       3  24.0      1      2  23.4500     0  0  1
# 887         1       1  26.0      0      0  30.0000     1  0  0
# 888         0       3  32.0      0      0   7.7500     1  1  0
#
# [889 rows x 9 columns]

# %%
df1[df1.Age==32]
# Out:
#      Survived  Pclass   Age  SibSp  Parch     Fare  male  Q  S
# 69          0       2  32.0      0      0  10.5000     1  0  1
# 73          1       3  32.0      0      0  56.4958     1  0  1
# 189         1       2  32.0      0      0  13.0000     0  0  1
# 205         0       3  32.0      1      0  15.8500     1  0  1
# 217         1       1  32.0      0      0  76.2917     0  0  0
# 381         0       3  32.0      0      0   7.9250     1  0  1
# 428         1       3  32.0      0      0   8.0500     1  0  1
# 518         0       3  32.0      0      0   7.8958     1  0  1
# 542         1       2  32.0      1      0  26.0000     1  0  1
# 568         1       3  32.0      0      0   7.8542     1  0  1
# 578         1       3  32.0      0      0   7.9250     1  0  1
# 631         1       1  32.0      0      0  30.5000     1  0  0
# 635         0       3  32.0      0      0   7.9250     1  0  1
# 656         0       3  32.0      1      1  15.5000     0  1  0
# ...

# %%
df1.groupby(by='Age')

# %%
from sklearn.metrics import accuracy_score
